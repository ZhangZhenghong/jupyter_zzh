# %%
from time import time
import functools

#装饰器写法
def outer(func):
    @functools.wraps(func)
    start = time()
    def wrapper(*args, **kwargs):
        func(*args, **kwargs)
    end = time()
    print(func.__name__, str(end - start))
    return wrapper
        
class Node():
    def __init__(self,item):
        self.item = item
        self.lchild = None
        self.rchild = None

class Mytree():
    def __init__(self):
        self.root = None

    def add(self, item):
        node = Node(item)
        if self.root is None:
            self.root = node
            return
        else:
            queue = [self.root]
            while queue:
                cur_node = queue.pop(0)
                if cur_node.lchild is None:
                    cur_node.lchild = node
                    return
                else:
                    queue.append(cur_node.lchild)
                if cur_node.rchild is None:
                    cur_node.rchild = node
                    return
                else:
                    queue.append(cur_node.rchild)
                    
    @outer
    def travel(self): 
        '''
        采用队列来遍历树，先遍历左子树，如果不为空，加到队列，再遍历右子树，如果不为空，加到队列，
        '''
        queue = [self.root]
        while queue:
            cur_node = queue.pop(0)
            #print(cur_node.item)
            if cur_node.lchild is not None:
                queue.append(cur_node.lchild)
            if cur_node.rchild is not None:
                queue.append(cur_node.rchild)
        return

    @outer
    def xian(self,root):
        '''
        递归调用自身
        '''
        root = root
        if root is None:
            return
        else:
            #print(root.item, end='')
            self.xian(root.lchild)
            self.xian(root.rchild)

    @outer
    def hou(self, root):
        root = root
        if root is None:
            return
        else:
            self.hou(root.lchild)
            self.hou(root.rchild)
            #print(root.item, end='')
            


if __name__ == '__main__':
    tree = Mytree()
    for i in range(1000):
        tree.add(i)

    tree.travel()
    tree.xian(tree.root)
    tree.hou(tree.root)
# Out:
# start travel
# total 0.001001119613647461
# start xian
# start xian
# start xian
# start xian
# start xian
# start xian
# start xian
# start xian
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0009622573852539062
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# total 0.0009622573852539062
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# total 0.0
# total 0.0009622573852539062
# start xian
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# total 0.0009975433349609375
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# total 0.0
# total 0.0009975433349609375
# total 0.0019598007202148438
# start xian
# start xian
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# total 0.0
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0009970664978027344
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# total 0.0009970664978027344
# total 0.0009970664978027344
# start xian
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# total 0.0
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# total 0.0
# total 0.0
# total 0.0009970664978027344
# total 0.002956867218017578
# start xian
# start xian
# start xian
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# total 0.0
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# total 0.0
# total 0.0009982585906982422
# start xian
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0009992122650146484
# total 0.0009992122650146484
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# total 0.0
# total 0.0009992122650146484
# total 0.0019974708557128906
# start xian
# start xian
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# total 0.0
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0009951591491699219
# total 0.0009951591491699219
# total 0.0009951591491699219
# start xian
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# total 0.0009965896606445312
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# total 0.0
# total 0.0009965896606445312
# total 0.001991748809814453
# total 0.003989219665527344
# total 0.006946086883544922
# start xian
# start xian
# start xian
# start xian
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# total 0.000997304916381836
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# total 0.0
# total 0.000997304916381836
# start xian
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# total 0.0
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# total 0.0
# total 0.0
# total 0.000997304916381836
# start xian
# start xian
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# total 0.0
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.011936664581298828
# total 0.011936664581298828
# total 0.013964414596557617
# start xian
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# total 0.0
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# total 0.0
# total 0.0
# total 0.013964414596557617
# total 0.014961719512939453
# start xian
# start xian
# start xian
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# total 0.001027822494506836
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.00099945068359375
# total 0.00099945068359375
# total 0.002027273178100586
# start xian
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# total 0.0
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# total 0.0
# total 0.0009968280792236328
# total 0.0030241012573242188
# start xian
# start xian
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# total 0.0
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# total 0.0
# total 0.0
# start xian
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# total 0.0
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0009958744049072266
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# total 0.0009958744049072266
# total 0.0009958744049072266
# total 0.0009958744049072266
# total 0.004019975662231445
# total 0.0189816951751709
# total 0.02592778205871582
# start xian
# start xian
# start xian
# start xian
# start xian
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# total 0.0
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0009980201721191406
# total 0.0009980201721191406
# total 0.0009980201721191406
# start xian
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# total 0.0
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# total 0.0
# total 0.0
# total 0.0009980201721191406
# start xian
# start xian
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# total 0.0009965896606445312
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.030918121337890625
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# total 0.030918121337890625
# total 0.031914710998535156
# start xian
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# total 0.0
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# total 0.0009644031524658203
# total 0.0009644031524658203
# total 0.03287911415100098
# total 0.03387713432312012
# start xian
# start xian
# start xian
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# total 0.0
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# total 0.0
# total 0.0
# start xian
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# total 0.0
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# total 0.0009968280792236328
# total 0.0009968280792236328
# total 0.0019948482513427734
# start xian
# start xian
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0009975433349609375
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# total 0.0009975433349609375
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0009999275207519531
# total 0.0009999275207519531
# total 0.0019974708557128906
# start xian
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0009953975677490234
# total 0.0009953975677490234
# start xian
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# start xian
# start xian
# total 0.0
# start xian
# total 0.0
# total 0.0
# total 0.0
# total 0.0